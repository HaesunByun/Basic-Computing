# %% [markdown]
# # 실습 WEEK4: 반복문

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 코딩수업(엘리스코딩)의 해당 주차 응시 기간을 확인해주세요.</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 1~100까지 출력하기
#
# 😄 숫자 1부터 100까지 출력해보세요.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 1
# 2
# 3
# ...
# 100
# ```

# %% [markdown]
# ### Problem: 티끌모아 태산
#
# 😄 부자가 되어 봅시다.
# 반복문을 이용하여 Output Sample과 같이 결과를 출력해보세요.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 티끌 모아 태산!!!
#
# 💰 동전 100원을 모았습니다.
# 💰💰 동전 200원을 모았습니다.
# 💰💰💰 동전 300원을 모았습니다.
# ……
# 💰💰💰💰💰💰💰💰💰💰 동전 1000원을 모았습니다.
#
# 산다. 산다. 집 산다!!!
# ```

# %% [markdown]
# ### Problem: 구구단 9단 출력하기
# 😄 구구단 9단을 출력하는 프로그램을 반복문을 이용하여 작성하세요.
#
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# ```

# %% [markdown]
# ### Problem: 단 입력받아 구구단 출력하기
# 😄 단을 입력 받아 그 단을 출력하는 프로그램을 반복문을 이용하여 작성하세요.
#
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 9
# ```
# Output Sample
# ```
# 단:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# ```

# %% [markdown]
# ### Problem: 2~9단까지 구구단 출력하기
# 😄2단부터 9단까지 구구단을 출력하는 프로그램을 반복문을 이용하여 작성하세요. 단과 단사이는 구별되게 한줄 공백을 출력하시오.
#
# ---
#
# Output Sample
# ```
# 2 단
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
#
# 3 단
# 3 * 1 = 3
# …
# 9 * 9 = 81
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께) 1~100까지 짝수만 출력하기
#
# 😄 숫자 1부터 100까지 짝수만 출력해보세요. 이때 if문을 활용하세요. 출력데이터가 길어서 엘리스에 올리지 않습니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 2
# 4
# 6
# ...
# 100
# ```

# %% [markdown]
# ### Problem: (함께) 로그인하기
# 😄 올바른 패스워드를 입력할 때까지 패스워드를 입력 받는 프로그램을 작성하세요. 올바른 패스워드를 입력하면 `로그인 성공`을 출력하세요.
# realPassword = 'pythonisfun'
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# pythonis
# funfunfun
# pythonisfun
# ```
# Output Sample
# ```
# 패스워드 입력:
# 패스워드 입력:
# 패스워드 입력:
# 로그인 성공
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# pythonis
# 111
# 1234
# 모르겠어
# 생각안나
# 어쩌지?
# pythonisfun
# ```
# Output Sample
# ```
# 패스워드 입력:
# 패스워드 입력:
# 패스워드 입력:
# 패스워드 입력:
# 패스워드 입력:
# 패스워드 입력:
# 패스워드 입력:
# 로그인 성공
# ```

# %% [markdown]
# ### Problem: (스스로) 횟수 제한 로그인 프로그램
# 😄 올바른 패스워드를 5회 안에 입력하지 않으면 더 이상 기회를 주지 않도록 프로그램을 작성하시오. 5회안에 올바른 패스워드를 입력하였다면 `로그인 성공`을, 입력하지 못하였다면 `5회 틀렸습니다. 로그인에 실패하셨습니다.`를 출력하세요.
# ※ 반드시 5번째에 올바른 패스워드를 입력하여 정확히 동작하는지 확인해보세요.
#
#
# ```
# realPassword = 'pythonisfun'
# ```
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# pythonis
# funfunfun
# pythonisfun
# ```
# Output Sample
# ```
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 로그인 성공
# ```
# <font color='blue'>`Test case-2`</font>
#
# ```
# pythonis
# funfunfun
# 123456
# abcdefg
# pythonisfun
# ```
# Output Sample
# ```
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 로그인 성공
# ```
#
# <font color='blue'>`Test case-3`</font>
#
# ```
# pythonis
# funfunfun
# 123456
# abcdefg
# idonotknow
# ```
# Output Sample
# ```
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 패스워드를 입력:
# 5회 틀렸습니다. 로그인에 실패하셨습니다.
# ```

# %% [markdown]
# ### Problem: (함께) 컴또번호 생성 프로그램
# 😄 로또에 당첨되어 봅시다. 반복문을 이용하여 1~45사이 컴또번호 6개를 생성하는 프로그램을 작성하시오. 단, 중복 번호를 허용한다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 1번째 번호는 4입니다.
# 2번째 번호는 6입니다.
# 3번째 번호는 6입니다.
# 4번째 번호는 24입니다.
# 5번째 번호는 11입니다.
# 6번째 번호는 43입니다.
# ```

# %% [markdown]
# ### Problem: (함께) 입력값에 따라 종료하기
# 😄 while문을 이용하여 -1를 입력받을때까지 양수를 입력받는 프로그램을 작성하시오. -1를 입력하면 '종료합니다.'를 출력하고 프로그램을 종료합니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 10
# 11
# 9
# 15
# 3
# -1
# ```
#
# Output Sample
# ```
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# 종료합니다.
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 100
# 121
# 19
# -1
# ```
# Output Sample
# ```
# Input:
# Input:
# Input:
# Input:
# 종료합니다.
# ```

# %% [markdown]
# ### Problem: (스스로) 입력값의 합구하기
# 😄 앞의 문제와 연속으로 -1를 입력하면 -1 이전까지 받은 수의 합을 출력하고 프로그램을 종료하는 코드를 작성하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 10
# 11
# 9
# 15
# 3
# -1
# ```
#
# Output Sample
# ```
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Sum: 48
# 종료합니다.
# ```

# %% [markdown]
# ### Problem: (스스로) 입력값의 평균구하기
# 😄 앞의 문제와 연속으로 -1를 입력하면 -1 이전까지 받은 수의 합과 평균을 출력하고 프로그램을 종료합니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 10
# 11
# 9
# 15
# 3
# -1
# ```
#
# Output Sample
# ```
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Sum: 48
# Average: 9.6
# 종료합니다.
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 입력값의 최댓값 구하기
# 😄 앞의 문제와 연속으로, -1를 입력하면 -1 이전까지 받은 수의 합과 평균, 최댓값을 출력하고 프로그램을 종료합니다.
# max의 초깃값은 아래와 같이 음의 무한대를 줍니다.
#
# ```
# maxNum = float('-inf')
# ```
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 10
# 11
# 9
# 15
# 3
# -1
# ```
#
# Output Sample
# ```
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Sum: 48
# Average: 9.6
# Max: 15
# 종료합니다.
# ```

# %% [markdown]
# ### Problem: 입력값의 최소값 구하기
# 😄 앞의 문제와 연속으로, -1를 입력하면 -1 이전까지 받은 수의 합과 평균, 최댓값, 최솟값을 출력하고 프로그램을 종료합니다.
# max와 min의 초깃값은 아래와 같이 음의 무한대, 양의 무한대를 줍니다.
#
# ```
# maxNum = float('-inf')
# minNum = float('inf')
# ```
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 10
# 11
# 9
# 15
# 3
# -1
# ```
#
# Output Sample
# ```
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Sum: 48
# Average: 9.6
# Max: 15
# Min: 3
# 종료합니다.
# ```

# %% [markdown]
# ### Problem: 동전 최소 개수
# 😄금액을 입력받아 최소 동전의 개수를 출력하는 코드를 반복문을 사용하여 작성하시오. 단, 금액은 10000원 이하, 10의 배수로 입력하고, 500원, 100원, 50원, 10원의 동전이 무한개 있다고 가정한다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 9820
# ```
# Output Sample
# ```
# 금액:
# 최소 동전 개수: 24
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 760
# ```
# Output Sample
# ```
# 금액:
# 최소 동전 개수: 5
# ```
