# %% [markdown]
# # 프로그램 제작 보고서

# %% [markdown]
# # 프로그램제작 보고서 작성방법
# • 이 템플릿의 파일명을 아래와 같이 변경해주세요.
# - 이름_학번_제작프로그램명.ipynb
# - 예) 이름_1234-56789_숫자야구게임.ipynb
#
# - 자신이 기획한 프로그램 또는 다른 학생이 기획한 프로그램을 코드로 구현하여 제작해 제출해 주세요.
# - 추가제작(선택)
#   - 난이도로 구별된 목록에서 제작해보고 싶은 프로그램을 추가적으로 제작합니다.
#   - 난도로 구분된 기획서 파일은 etl > 게시판 > 프로그램 기획서 제출 게시판에 있습니다.
#
# - 마감기한 : <font color="red">제출기한: 2024년 7월 14일 23시 59분 59초</font>
# - 이 파일에 코딩하여 이 파일을 etl에 제출합니다.
# - 제작한 파일 다운로드 및 제출 방법: 파일메뉴 > 다운로드 > .ipynb 다운로드 > 로컬 컴퓨터에 다운로드 받은 파일을 <font color="red"> 과제 >[중간평가-2단계] 프로그램 제작에 업로드</font>합니다.

# %% [markdown]
# # 평가 기준
#
# **ChatGPT의 도움 30% 이내!!! ChatGPT의 도움이 물씬 풍기는 코드의 경우 0점처리!!**
#
#
# ```
# 함수활용(5점)
# - 함수를 활용하면 훨씬 효율적으로 코딩할 수 있었음에도 미사용한 경우 0
# - 함수를 활용 정도에 따라 1~5
# ```
# ```
# container  data type 활용(5점)
# - 리스트, 딕셔너리 등을 활용하면 훨씬 효율적으로 코딩할 수 있었음에도 미사용한 경우 0
# - 리스트, 딕셔너리, 튜플, 셋 등의 활용 정도에 따라 1~5
# ```
# ```
# 보고서 작성(5점)
# - 기본점수 5점에서 아래 항목들에 대해 감점
# - 보고서에 자신의 코드에 대한 설명을 전혀 작성하지 않은 경우 -3
# - 보고서에 자신의 코드에 대한 설명이 부족한 경우 -1
# - 보고서에 기획서 내용을 표시하지 않은 경우 -1
# - 보고서에 틀린 표현이 있는 경우 개당 -1
# - 보고서 점수는 0점 미만일 수 없음
# ```
# ```
# 기타평가
# - 아래 항목들에 대해 전체점수에서 감점이 있을 수 있음
# - 미완성 상태로 제출하였거나 중대한 오류로 인해 아예 실행되지 않음
# - 라이브러리를 import하지 않아  코드가 실행되지 않음
# - 기획서에 수록되었으나 미구현한 항목이 있음
# - 기획서에 수록된 내용을 틀리게 구현함
# - 소스코드를 보고서 형태로 작성하여 실행이 불가능 함
# - 실행 결과를 왜곡하지는 않으나, 문법 상 명백한 오류가 있음
# - 특정 조건 하에서 코드가 오류를 발생시킴
# - 특정 조건 하에서 코드가 잘못된 결과를 출력함
# - 코드 실행 결과에 전혀 영향을 주지 못하는 불필요한 요소를 포함함
# - 출력에서의 온점, 띄어쓰기 등 극히 사소한 항목의 경우 그 구현 여부를 평가에 반영하지 않음
# ```
#
# ```
# 제작 난이도(15점)
# - 메인 프로그램 제작: 상:7~10점, 중:4~7점, 하:3~6점
# - 추가 프로그램 제작: 상: 5점, 중: 4점, 하: 3점
# - 추가 프로그램을 제작한 경우에는 추가 점수는 있으나 평가기준으로 인한 감점은 없습니다.
# - 제작 난이도 점수는 최대 15점을 넘을 수 없습니다.
#   - 예1) 메인 제작(상) + 추가 제작(상) = 15점
#   - 예2) 메인 제작(상) + 추가 제작(중) + 추가 제작(하) = 15점
#   - 예3) 메인 제작(중) + 추가 제작(중) + 추가 제작(하) = 14점
# - 난도는 제가 보는 관점에서 바뀔 수 있습니다.
# - 프로그램을 제작해서 제출했더라도 기획서 미제출시 최대 받을 수 있는 점수는 기본 점수로 제한합니다.
# ```
#
# ※ 프로그램 실행을 멈추는 오류가 아닌 단순 Warning은 평가에 반영하지 않음
#
# <font size=4 color="red">
# ※ 늦은 제출 시  1일당 1점 감점<br>
# ※ 개인프로젝트 미제출시 8주차 결석처리</font>

# %% [markdown]
# # 1: 제작프로그램명:
# - 제작자 정보(학과(부)/학번/성명):

# %% [markdown]
# ## 1.기획서 내용
# - 제작요청자의 기획서 내용이 들어있는 가~다(요구사항 포함) 셀을 그대로 복사하여 붙여넣어 주세요. 기획서 작성자가 본인이여도 동일하게 해주세요.

# %% [markdown]
# ##2.전체코드
# - 프로그램 제작이 끝나면 전체코드를 아래 하나의 셀에 모두 넣어주세요.

# %% [markdown]
# ## 3.부분코드 작성요령
#
# - 부분코드는 기획 요구사항별로 혹은 기능별로 자유롭게 나누시면 됩니다.
# - 대체적으로 함수를 기준으로 나누시면 좋습니다.
# - 부분코드의 셀은 필요한만큼 추가하시면 됩니다.
# - 설명과 구현방법을 자세히 작성하세요.

# %% [markdown]
# ## 3-1. 부분코드1

# %% [markdown]
# ## 3-2. 부분코드2

# %% [markdown]
# ## 3-3. 부분코드3

# %% [markdown]
# ## 4.소감
# - 프로그램을 제작하면서 어려웠던 점, 느낀 점 등을 자유롭게 기술하시면 됩니다.

# %% [markdown]
# # 2: 추가 제작프로그램명:
#
# - 제작자 정보(학과(부)/학번/성명):
#
# • 추가프로그램을 제작하는 경우 1.기획서 내용 ~ 4.소감까지의 셀을 그대로 복사하여 붙여넣기 한 후 작성하시면 됩니다.
