# %% [markdown]
# # 실습 WEEK1: 엘리스코딩 첫 걸음

# %% [markdown]
# ## 시작하기
# ### Problem: (함께)Hello World! 출력하기
#
# 😄 print() 함수는 ( )안에 있는 값을 화면에 출력하는 기능을 한다.
# 코드를 작성하여 Output Result에서와 같이 문자열 Hello World!와 완전히 동일하게 출력하시오. 결과가 동일하게 출력되었다면 이 코드를 복사하여 엘리스코딩으로 가서 붙여넣기 한 후 동일한 결과를 출력해봅시다.
#
# ---
# Output Result
# ```
# Hello World!
# ```

# %% [markdown]
# ## 셀 단위 실행 vs. 통 실행
# ### Problem: (스스로)수식으로 표현해보기
#
# 😄다음을 수식으로 표현해보고 결과를 출력하시오.
#   - 정수 50을 정수 4로 나눈 몫을 정수로 구하시오.
#   - 정수 50을 정수 4로 나눈 나머지를 구하시오.
#
# ---
# Output Results
# ```
# 30
# 25
# 105.0
# 0.5
# 0.5
# 12
# 2
# 1000
# ```
