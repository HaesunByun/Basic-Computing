# %% [markdown]
# # Chapter 12. Pandas II

# %% [markdown]
# :::{admonition} 학습목표와 기대효과
# :class: info
# - 학습목표
#   - 파일 입출력 방법을 익혀보자.
#   - 데이터 처리에 관련된 함수를 익혀보자.
#   - ChatGPT를 활용하여 파이썬 코드를 작성해보자.
# - 기대효과
#   - ChatGPT와 pandas를 활용하여 다양한 데이터 연산 및 분석에 필요한 기능을 쉽고 빠르게 코딩할 수 있다.
# :::

# %% [markdown]
# ## 파일 입출력
#
# |파일 형식|읽기|쓰기|
# |:----------:|:----------|:----------|
# |MS Excel|read_excel| to_excel|
# |CSV|read_csv| to_csv|
# |JSON|read_json|to_json|
# |HTML|read_html|to_html|
# |Local clipboard|read_clipboard|to_clipboard|
# |HDF5 format|read_hdf|to_hdf|
# |SQL|read_sql|to_sql|

# %% [markdown]
# - csv 파일을 불러올 때
#   - pd.read_csv('파일명', index_col=칼럼번호, encoding='인코딩방법')
#     - index_col:칼럼번호를 설정인덱스로 지정한다.
#     - usecols: 사용할 칼럼번호를 지정한다.
#     - header: 헤더(칼럼)으로 선택할 헤더를 지정한다.
#     - encoding: 한글이 깨질때에는 encoding 옵션에 'euc-kr'을 넣어준다.
#     - 이 외에도 많은 옵션이 있다.
#
# - excel파일을 불러올 때
#   - pd.read_excel('파일명', encoding='인코딩방법')

# %% [markdown]
# :::{admonition} 인코딩 & 디코딩
# :class: tip
# - 인코딩(encoding)는 코드화 또는 암호화로 불리우며, 문자열을 바이트코드로 변환하는 것을 의미한다.
# - 파이썬에서는 문자열을 유니코드로 처리하는데 유니코드를 utf-8, euc-kr, ascii 형식의 인코딩방식을 사용하여 바이트코드로 변환한다. 예를 들어,
# ```
# x='한글'
# encoded = x.encode('utf-8')
# print(f'Output: {encoded}')
# ```
# Output: b'\xed\x95\x9c\xea\xb8\x80'
#
# - 여기서 결과로 나온 b'\xed\x95\x9c\xea\xb8\x80'가 바이트 코드이다.
#
# - 디코딩(decoding)은 역코드화 또는 복호화로 불리우며, 바이트코드를 문자열로 변환하는 것을 의미한다.
# - 이때 디코딩에서도 인코딩 시 사용했던 것과 동일한 인코딩 방식(utf-8, euc-kr, ascii 등)이 사용되어야 한다.
# ```
# decoded = encoded.decode('utf-8')
# print(f'Output: {decoded}')
# ```
# Output: 한글
#
# - 인코딩을 하는 이유는 언어마다 표준화된 규격으로 문자집합을 만들고, 이러한 문자집합을 가지고 정보의 형태 표준화, 보안, 저장 공간 절약 등의 다양한 목적으로 부호화하여 사용하기 위한 것이다.
#
# :::

# %% [markdown]
# - 파일 읽고 저장하기

# %%
import pandas as pd
scores = [[84,87,78], [21,15,84], [87,84,76], [100,87,99],[59,99,59],[46,77,56]]
names=['철수','영이','길동','미영','순이','철이']
lectures=['국어','수학','영어']
d1 = pd.DataFrame(scores, index=names, columns=lectures)
d1

# %%
# 엑셀로 저장하기
d1.to_excel('sample.xlsx')

# %%
# 엑셀 읽어오기
d2 = pd.read_excel("sample.xlsx")
d2

# %% [markdown]
# - index_col 옵션은 인덱스 칼럼을 지정하여 읽어올 수 있게 해준다.

# %%
d2 = pd.read_excel("sample.xlsx", index_col=0)
d2

# %%
# csv로 저장하기
d2.to_csv('sample.csv', encoding='euc-kr')

# %%
d2 = pd.read_csv('sample.csv', encoding='euc-kr', index_col=0)
d2

# %% [markdown]
# ## 자료형 다루기
# - .astype(자료형)

# %%
d2 = d1.astype('str')
d2

# %%
d2.sum()

# %% [markdown]
# ## 누락값 처리하기

# %% [markdown]
# - 누락 데이터 확인
#   - isnull(): 누락 데이터이면 True, 유효한 데이터이면 False를 반환
#   - notnull():유효한 데이터이면 True, 누락데이터이면 False를 반환

# %%
scores = [[84,87,78], [21,15,84], [87,84,76], [100,87,99],[59,99,59],[46,77,56]]
names=['철수','영이','길동','슬기','순이','철이']
lectures=['국어','수학','영어']
d2 = pd.DataFrame(scores, index=names, columns=lectures)
d2

# %%
d3=d1+d2
d3

# %%
d3.isnull()
#d3.notnull()

# %% [markdown]
# - 누락데이터의 개수를 확인하려면 .isnull().sum()으로 null인 데이터의 개수를 합한다.

# %%
d3.isnull().sum()

# %% [markdown]
# - 누락 데이터 제거
#   - 행제거: .dropna(subset=칼럼명, how='any'/'all', axis=0, thresh=개수)
#   - 열제거: .dropna(axis=1, thresh=개수)
#   - how
#     - any: 하나라도 비어 있으면 삭제
#     - all: 데이터가 모두 비어 있으면 삭제
#   - thresh: 유효한 값의 개수가 thresh보다 작은 행이나 열을 삭제

# %%
d4=d3.dropna(axis=0)
d4

# %% [markdown]
# - 누락 데이터 치환
#   - .fillna(값)

# %%
min_kor = d3['국어'].min()
d3['국어'].fillna(min_kor, inplace=True)
d3

# %% [markdown]
# ## 중복데이터 처리

# %% [markdown]
# - .duplicated(): 중복된 행이면 True, 아니면 False이다.

# %%
d3
# Out:
#        국어     수학     영어
# 길동  174.0  168.0  152.0
# 미영   42.0    NaN    NaN
# 순이  118.0  198.0  118.0
# 슬기   42.0    NaN    NaN
# 영이   42.0   30.0  168.0
# 철수  168.0  174.0  156.0
# 철이   92.0  154.0  112.0

# %%
d3.duplicated()

# %%
d3['국어'].duplicated()

# %% [markdown]
# - 중복행 제거:  .drop_duplicates(subset=컬럼명리스트)

# %%
d3

# %%
d3.drop_duplicates(subset=['국어', '영어'])

# %% [markdown]
# ## 시계열 데이터
# - 다른 자료형을 시계열 객체로 변환
# - to_datetime(): 문자열을 timestamp로 변환

# %%
data = [['1990-03-02', 90], ['1991-08-08', 95], ['1990-11-22',90], ['1991-01-05', 88]]
names=['철수','영이','길동','미영']
column=['생년월일','점수']
d1 = pd.DataFrame(data, index=names, columns=column)
d1

# %% [markdown]
# - 생년월일을 확인해보면 object 타입이다.

# %%
d1.info()

# %% [markdown]
# - object 타입의 생년월일을 시계열 데이터타입인 datetime형으로 바꿔보자.

# %%
d1['생년월일'] = pd.to_datetime(d1['생년월일'])
d1

# %% [markdown]
# - datetime으로 변환후 확인해보면 타입이 변경된 것을 알 수 있다.

# %%
d1.info()

# %% [markdown]
# - 시계열 데이터 활용
#   - 날짜 데이터를 분리할 수 있다.
#   - 연-월-일 정보에서 연,월,일 추출: dt.year, dt.month, dt.day를 사용

# %%
d1['년'] = d1['생년월일'].dt.year
d1['월'] = d1['생년월일'].dt.month
d1['일'] = d1['생년월일'].dt.day
d1

# %% [markdown]
#  - 연-월-일 정보에서 연-월 추출: dt.to_period()를 사용
#  - df.to_period(freq=None, axis=0, copy=True)
#   - freq : 원하는 시간 단위로 변환('Y','M','D', 'W')
#   - axis : 변환할 기준 축
#   - copy : 사본을 형성할지 여부

# %%
d1

# %%
d1['년월'] = d1['생년월일'].dt.to_period(freq='M')
d1
# Out:
#          생년월일  점수       년월
# 철수 1990-03-02  90  1990-03
# 영이 1991-08-08  95  1991-08
# 길동 1990-11-22  90  1990-11
# 미영 1991-01-05  88  1991-01

# %% [markdown]
# - 날짜 인덱스 활용

# %%
d2 = d1.set_index(['생년월일'])
d2

# %%
d2.index

# %%
d2.loc['1990-03']

# %%
d2.loc['1990']

# %% [markdown]
# - 정확한 인덱스로 시작해야 한다.

# %%
d2.loc['1990-03-02':'1990-12-31']

# %%
today = pd.to_datetime('2024-05-14')
today

# %%
d2['날짜_차이'] = today-d2.index
d2

# %% [markdown]
# ## ChatGPT란

# %% [markdown]
# - ChatGPT는 미국의 AI 연구재단 OpenAI가 2022년 11월 공개한 초거대 언어모델 GPT-3.5 기반 대화형 인공지능 챗봇
# - ChatGPT는 'Generative Pre-trained Transformer'의 약자
# - Generative(생성형), Pre-trained(미리 학습된) Transformer(변환기)
#
#
# - 현재 ChatGPT 홈페이지(https://chatgpt.com/) 에서 누구나 가입 후 사용 가능.
#
# - 사용자가 채팅 하듯 질문을 입력하면 ChatGPT는 학습한 데이터를 기반으로 '사람처럼' 문장을 만들어 답을 해줌
# - 마치 진짜 사람과 대화하는 것처럼 자연스럽게 질문과 답변을 주고받을 수 있음
# - 단순 정보 짜깁기뿐 아니라 에세이・소설・시 등 다양한 창작물, 심지어 프로그래밍 코드까지 생성한다는 점에서 화제가 됨.

# %% [markdown]
# 출시일
# 2022. 11. 30 출시
# 2023. 3. 14 GPT-4 출시
# 2023. 3. 23 chat GPT plugins 공개
# 지속적 업데이트
#
#
# 출처 : 나무위키
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/chatGPT_logo.png" width=400></div>

# %% [markdown]
# ### ChatGPT 가입하기
#
# https://chatgpt.com/
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/chatgpt1.png" width=500 ></div>

# %% [markdown]
# ## ChatGPT에게 질문하기

# %% [markdown]
# - 효과적인 AI 프롬프트 원칙
#   - 명확하고 구체적인 요구 사항 제시
#   - 적절한 제약 조건과 지침 제공
#   - AI의 이해를 돕는 맥락 제공

# %% [markdown]
# Q. ChatGPT에게 질문해보세요.
# - ChatGPT란 뭐야?
# - 인공지능에 대한 시를 작성해줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/chatgpt2.PNG" width=500 ></div>
# - ChatGPT 활용 분야를 알려줘
# - Chat GPT는 접속이 원활한 시간이 언제야?
# - Chat GPT 유료와 무료의 차이를 설명해줘
# - 세상에서 가장 아름다운 곳은?
# - 수업 첫날은 무엇을 하면 좋을까?
# - 세익스피어 작품에 대해 가르쳐 줘

# %% [markdown]
# - 'hello world'를 출력하는 파이썬 코드를 작성해줘

# %% [markdown]
# ## 뤼튼(wrtn)
# - 국내 기업 뤼튼 테크롤로지스가 개발한 한국의 대표적인 AI 플랫폼 서비스이다.
# - 2021년에 설립된 뤼튼 테크놀로지스는 AI 기술을 활용하여 다양한 서비스를 제공하고 있다.
# - ChatGPT 기반 한국어에 특화(최적화)되었으며, ChatGPT 4.0을 포함하여 무료로 서비스를 제공하고 있다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic19.PNG" width="200"></div>

# %% [markdown]
# - https://wrtn.ai/ 접속해보자.
# - 회원가입이 되어있지 않다면 회원가입 후에 로그인해보자.
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic20.PNG" width="400"></div>
# - 뤼튼은 다양한 AI 모델을 제공하고 있어서 원하는 모델을 선택하여 질문할 수 있다.
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic21.PNG" width="400"></div>

# %% [markdown]
# AI검색, GPT-4, GPT-3.5, Claude(클로드) 등 종류별 동일한 질문을 던져 답을 확인해보자.
#
# <font color="red">Q</font>. 뤼튼이 뭐야?

# %% [markdown]
# 코드를 작성해서 질문을 던지면 이에 대한 설명도 제공해준다.
# ```
# print('안녕하세요.')
# ```
#
# GPT-4, GPT-3.5, claude로 선택한 후 그림을 그려보자.(AI검색, PaLM2는 제외)
#
# <font color="red">Q</font>. [넓은 우주 공간이 배경으로 펼쳐져 있으며, 반짝이는 별들과 소용돌이 치는 은하들이 그 공간을 채우고 있습니다. 중앙에는 매혹적이고 신비로운 색상의 우주 먼지 구름이 황금빛 털의 골든 리트리버 개를 둘러싸고 있습니다.]] 그려줘
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic22.PNG" width="400"></div>

# %% [markdown]
# <font color="red">Q</font>. [[화창한 날씨에 언덕에 피어있는 해바라기가 가득한 풍경화]] 반고흐 화풍으로 그려줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic23.PNG" width="400"></div>
#
# <font color="red">Q</font>. 시내버스를 피카소 화풍으로 그려줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic24.PNG" width="400"></div>
#
# <font color="red">Q</font>. 해가 뜨는 바다풍경을 모네 화풍으로 그려줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic25.PNG" width="400"></div>
#
#
# <font color="red">Q</font>. 하늘을 나는 노란 풍선과 양모양 구름이 있는 마을을 칸딘스키 화풍으로 그려줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic26.PNG" width="400"></div>
#
# <font color="red">Q</font>. 맛있게 음식을 먹은 사람을 로이 리히텐슈타인 화풍으로 그려줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic27.PNG" width="400"></div>
#
# <font color="red">Q</font>. 2차 세계대전에서 싸우는 탱크를 그려줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic28.PNG" width="400"></div>

# %% [markdown]
# ## 코랩의 AI코딩
#
# - 코랩에서도 AI로 코드를 생성할 수 있다.
# - 코랩의 설정(톱니바퀴)버튼에서 AI지원을 클릭하여 AI기능을 on/off 시킬 수 있다.
# <div align="center"><img src="https://haesunbyun.github.io/common/images/colabai.PNG" width=400>
#
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/AIcoding.PNG" width=400>
# </div>

# %% [markdown]
# - 'Hello world!'를 출력한다.

# %% [markdown]
# # Practice-1: Chat-GPT로 서울인구데이터 활용해보기
# - 데이터 다운로드 사이트 : https://data.seoul.go.kr/
# - 검색어: 서울시 자치구별 인구수
# - 목표:
#   - 각 구별 한국인의 비율 구하기
#   - 각 구별 외국인의 비율 구하기
#   - 각 구별 고령자의 비율 구하기
#   - 인구수가 적은 순서대로 5개 구 출력하기
#   - 외국인 수 내림차순 정렬하기
#   - 고령자 비율 오름차순 정렬하기
#   - 인구수가 가장 많은 자치구와 인구수 최대값 구하기
#   - 인구수가 가장 적은 자치구와 인구수 최소값 구하기
#   - 인구수와 고령자수 간의 상관 관계 구하기

# %% [markdown]
# 😄 필요한 칼럼만 불러와서 데이타프레임 생성하기
# - 다운로드한 파일을 열어서 아래의 옵션에 사용할 칼럼을 살펴본다.
# - header: 칼럼 이름 지정
# - index_col: index로 지정할 칼럼 지정
# - use_cols: 사용할 칼럼 지정

# %% [markdown]
# 😄 데이타프레임 칼럼명 변경하기

# %% [markdown]
# 😄 데이타프레임 인덱스 설정하기

# %% [markdown]
# 😄 불필요한 행 삭제하기

# %%
# Out:
#          인구수     한국인    외국인     고령자
# 구별
# 종로구   150550  139498  11052   29127
# 중구    131812  121602  10210   26302
# 용산구   223433  209849  13584   39671
# 성동구   284258  276964   7294   50098
# 광진구   350925  335105  15820   57768
# 동대문구  360211  341987  18224   67880
# 중랑구   387433  381966   5467   80250
# 성북구   436901  424881  12020   81280
# 강북구   291372  286400   4972   69366
# 도봉구   308864  306346   2518   71572
# 노원구   501727  497064   4663   97596
# 은평구   470185  466007   4178   95209
# 서대문구  320378  305986  14392   58797
# 마포구   374962  363645  11317   58592
# 양천구   437774  434528   3246   77423
# 강서구   567159  561386   5773  103825
# 구로구   414271  391387  22884   81360
# 금천구   240680  227160  13520   46198
# 영등포구  397942  375148  22794   68650
# 동작구   389576  378649  10927   71335
# 관악구   497827  481958  15869   86455
# 서초구   412275  407840   4435   66556
# 강남구   559720  554280   5440   88662
# 송파구   659661  653736   5925  110520
# 강동구   465549  461367   4182   84456

# %% [markdown]
# 😄 값 구하기
# ```
# 각 구별 한국인의 비율 구하기
# 각 구별 외국인의 비율 구하기
# 각 구별 고령자의 비율 구하기
# ```

# %%
# Out:
#          인구수     한국인    외국인     고령자     한국인 비율    외국인 비율     고령자 비율
# 구별
# 종로구   150550  139498  11052   29127  92.658917  7.341083  19.347061
# 중구    131812  121602  10210   26302  92.254120  7.745880  19.954177
# 용산구   223433  209849  13584   39671  93.920325  6.079675  17.755211
# 성동구   284258  276964   7294   50098  97.434021  2.565979  17.624130
# 광진구   350925  335105  15820   57768  95.491914  4.508086  16.461637
# 동대문구  360211  341987  18224   67880  94.940743  5.059257  18.844511
# 중랑구   387433  381966   5467   80250  98.588917  1.411083  20.713259
# 성북구   436901  424881  12020   81280  97.248805  2.751195  18.603757
# 강북구   291372  286400   4972   69366  98.293590  1.706410  23.806680
# 도봉구   308864  306346   2518   71572  99.184754  0.815246  23.172659
# 노원구   501727  497064   4663   97596  99.070610  0.929390  19.452013
# 은평구   470185  466007   4178   95209  99.111414  0.888586  20.249264
# 서대문구  320378  305986  14392   58797  95.507806  4.492194  18.352384
# 마포구   374962  363645  11317   58592  96.981827  3.018173  15.626117
# 양천구   437774  434528   3246   77423  99.258522  0.741478  17.685609
# 강서구   567159  561386   5773  103825  98.982120  1.017880  18.306154
# 구로구   414271  391387  22884   81360  94.476080  5.523920  19.639318
# 금천구   240680  227160  13520   46198  94.382583  5.617417  19.194781
# 영등포구  397942  375148  22794   68650  94.272030  5.727970  17.251258
# 동작구   389576  378649  10927   71335  97.195156  2.804844  18.310933
# 관악구   497827  481958  15869   86455  96.812346  3.187654  17.366475
# 서초구   412275  407840   4435   66556  98.924262  1.075738  16.143593
# 강남구   559720  554280   5440   88662  99.028085  0.971915  15.840420
# 송파구   659661  653736   5925  110520  99.101811  0.898189  16.754060
# 강동구   465549  461367   4182   84456  99.101706  0.898294  18.141162

# %% [markdown]
# 😄 값에 따라 정렬하기
# ```
# - 인구수가 적은 순서대로 5개 구 출력하기
# - 외국인 수 내림차순 정렬하기
# - 고령자 비율 오름차순 정렬하기
# ```

# %%
# Out:
#         인구수     한국인    외국인    고령자     한국인 비율    외국인 비율     고령자 비율
# 구별
# 중구   131812  121602  10210  26302  92.254120  7.745880  19.954177
# 종로구  150550  139498  11052  29127  92.658917  7.341083  19.347061
# 용산구  223433  209849  13584  39671  93.920325  6.079675  17.755211
# 금천구  240680  227160  13520  46198  94.382583  5.617417  19.194781
# 성동구  284258  276964   7294  50098  97.434021  2.565979  17.624130

# %% [markdown]
# 😄 데이타프레임 필요한 통계내기
# ```
# - 인구수가 가장 많은 자치구와 인구수 최대값 구하기
# - 인구수가 가장 적은 자치구와 인구수 최소값 구하기
# - 인구수와 고령자수 간의 상관 관계 구하기
# ```

# %%
# Out:
#              인구수       한국인       외국인       고령자    한국인 비율    외국인 비율    고령자 비율
# 인구수     1.000000  0.998971 -0.234866  0.947956  0.712619 -0.712619 -0.356521
# 한국인     0.998971  1.000000 -0.278719  0.950877  0.739207 -0.739207 -0.341808
# 외국인    -0.234866 -0.278719  1.000000 -0.306147 -0.752802  0.752802 -0.223657
# 고령자     0.947956  0.950877 -0.306147  1.000000  0.768441 -0.768441 -0.051449
# 한국인 비율  0.712619  0.739207 -0.752802  0.768441  1.000000 -1.000000  0.025606
# 외국인 비율 -0.712619 -0.739207  0.752802 -0.768441 -1.000000  1.000000 -0.025606
# 고령자 비율 -0.356521 -0.341808 -0.223657 -0.051449  0.025606 -0.025606  1.000000

# %%
# Out:
# 인구수와 고령자 간의 상관 관계: 0.95
