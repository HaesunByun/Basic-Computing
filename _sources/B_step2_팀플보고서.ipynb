# %% [markdown]
# # 팀프로젝트 안내
# 주제를 정하여 문제 정의를 하고, 데이터를 수집, 정제, 분석, 시각화하여 제출하세요.
#
# - 팀 주제 : 팀원들과 자유롭게 결정
# - 발표회 일시:
#     - <font color="red">001강좌, 002강좌: 6월 12일 수업시간
#     - 003강좌: 6월 14일 수업시간</font>
#
# - 발표자료 1차 제출 기한 :
#     - <font color="red">001강좌, 002강좌: 6월 12일 수업시작 30분 전
#     - 003강좌: 6월 14일 수업시작 30분 전</font>
#
# - 최종 자료 제출 기한: <font color="red">발표일 23시 59분</font>

# %% [markdown]
# ---

# %% [markdown]
# # 가. 팀프로젝트 주제 제안서 제출 안내
# - 아래 형식에 맞게 팀 프로젝트 주제 제안서를 작성해 주세요.
# - 제출 자료: 지금 작성하고 있는 .ipynb파일
# - 제출 기한: <font color="red">5월 15일까지</font>
# - 팀에서 대표 학생 한 명만 제출
# - 제출장소: <font color="green"><strong> 게시판 >> 팀프로젝트 제출 게시판</strong></font>

# %% [markdown]
# ## 1.문제 정의

# %% [markdown]
# ## 2.목표

# %% [markdown]
# ## 3.데이터 수집 방법

# %% [markdown]
# ## 4.분석 방법

# %% [markdown]
# ## 5.시각화 내용

# %% [markdown]
# ---

# %% [markdown]
# # 나. 팀 프로젝트 발표 자료 제출 안내

# %% [markdown]
# ## 1.발표 타입 선택
#
#   - 발표 타입 : 대면 발표 또는 동영상 발표 선택
#   - 팀에서 대표 학생 한 명만 투표
#   - 발표 타입 선택 기한
#     - <font color="red"> 001, 002강좌: 6월 5일까지
#     - 003강좌: 6월 7일까지</font>
#   - 선택 장소 : <font color="green"><strong>퀴즈 >> 기말 팀 프로젝트 발표 타입을 선택</strong></font>

# %% [markdown]
# ## 2.발표 파일 제출
#
# - [발표 포스터 양식](https://https://github.com/HaesunByun/Basic-Computing/blob/gh-pages/_sources/PPT_template.pptx?raw=True)
# - 발표 시간 7분~10분(준비시간 포함 최대 10분 이내)
# - 발표 자료에 데이터의 출처를 반드시 넣습니다.
# - 발표 자료에 기본적인 설치 & 설정 내용은 넣지 않습니다.(예: 한글 폰트 설정, 크롬 옵션 설정 등 넣지 말 것)
#
# - 대면 발표 팀: PDF 제출
# - 동영상 발표 팀: PDF, 발표 동영상 파일 제출
# - 제출 장소: <font color="green"><strong>게시판 > 팀 프로젝트 제출 게시판</strong></font>
#   - 제출한 주제제안서의 댓글로 제출합니다.
# - 발표자료 제출 기한 :
#     - <font color="red">001강좌, 002강좌: 6월 12일 수업시작 30분 전
#     - 003강좌: 6월 14일 수업시작 30분 전</font>
# - 발표 당일, 발표 준비 시간을 줄이기 위해 반드시 수업시작 30분전까지 업로드해 놓으시기 바랍니다.

# %% [markdown]
# # 다. 팀프로젝트 최종 자료 제출 안내

# %% [markdown]
# ### 제출자료 A
# - 제출자료 A은 압축파일로 만들어 팀에서 대표 학생 한 명만 제출
# - 제출 장소: <font color="green"><strong> 과제 >  [기말평가]팀 프로젝트에 제출</strong></font>
#
# 1. 코드 + 보고서 : 지금 작성하고 있는 .ipynb파일
#
# 2. 발표 PPT 파일
#
# 3. 팀프로젝트에서 사용한 데이터 파일(있을 시)

# %% [markdown]
# ### 제출자료 B
#
# 팀원 참여도 평가
#
# - 모든 학생이 개별 제출
# - 제출 장소 : <font color="green"><strong> 과제>기말> [기말평가] 참여도 평가 </strong></font>를 클릭하여 텍스트로 작성
# - 5점 기준(참여도가 높을 수록 5점에 가까움)
# - 본인의 참여도도 반드시 포함할 것
# - 간단하게 역할 분담 및 참여도 평가 의견과 함께 점수를 적어주세요.
# ```
# 팀명 및 주제: ***튜터_팀명_주제
# 팀원(본인):
# 팀원:
# 팀원:
# 팀원:
# 팀원:
# ```

# %% [markdown]
# # 팀 프로젝트 평가 기준
#
# ```
# 1. 주제선정(5점)
# - 관심도 높은, 흥미로운, 의미가 있는 주제를 선정했는지 판단
# ```
# ```
# 2. 발표내용  및  구성(12점)
# - 발표 구성이 적절한지 판단(2점)
# - 발표 내용이 충실한지 판단(5점)
# - 발표 능력과 태도 판단(5점)
# ```
# ```
# 3. 결과(8점)
# - 그래프 결과와 결론을 잘 도출 했는지 판단
# - 의미 있는 결론인지 판단
# ```
# (1+2+3)는 교수자+조교+튜터가  평가한  점수의  평균점수로 부여
#
# ```
# 5. 팀원평가(5점)
# - 팀원 각자가 제출한 팀원평가 점수에 따라 교수자가 최종 평가 팀원평가 점수 부여
# ```
#
# <font color="red">
#
# ※ 팀원이 팀플 미참여시 해당 팀원에 대해 14주차 실습과 15주차 이론/실습에 대해 결석처리되며, 구제 기회 없습니다.
#
# ※ 팀플에 참여는 했으나 소극적참여(팀원  과반 이상이  팀원평가  2점 이하의  점수를  부여한  경우) 팀프로젝트 점수 30점 가운데 기본점수 5점만 부여합니다.</font>

# %% [markdown]
# # 팀 프로젝트 작성요령
# • 이 템플릿의 파일명을 아래와 같이 변경해주세요.
# - 튜터명_팀번호_팀명_팀프로젝트명.ipynb
# - 예) 천예원튜터_2팀_하나로_인구수와 CCTV수 관계 분석.ipynb
#
# • `0.프로젝트 요약`을 공백포함 500글자 이내로 적어주세요.
#
# • `1.실행환경`에 코드가 실행되는 환경을 적어주세요.
#
# • `2.사용된 데이터 출처`에 데이터를 어디에서 어떻게 수집했는지 적어주세요.
#
# • `3.전체코드`에 전체 코드를 하나의 셀에 넣어주세요.(준비작업 설치 및 설정 코드는 분리, 예를 들어 selenium 설정 및 설치 등)
#
# • `4.부분코드`에는 부분 코드와 함께 코드의 설명을 작성해주세요.
#
# • `5.소감`에는 팀프로젝트를 진행하면서 역할 분담, 어려웠던 점, 느낀 점 등을 팀원 모두 자유롭게 기술해주세요.

# %% [markdown]
# # 팀 프로젝트명:
# - 팀원1(학과(부)/학번/성명):
# - 팀원2(학과(부)/학번/성명):
# - ......

# %% [markdown]
# ## 0.프로젝트 요약(공백포함 500글자 이내)
# - 목적/내용/결론
#
#
# 예)대학가별 식당 상권의 전반적인 특성을 알아보고자 하였다. 종류별 식당 분포도를 통해 해당 상권에서는 어떠한 종류의 음식이 강세인지, 리뷰 수 분석을 통해 실제로 어떤 종류의 음식집이 인기가 많은지를 조사하였다. 식신 사이트를 크롤링해 정보를 수집했고, 막대 그래프와 원 그래프 등으로 시각화했다. 그 결
# 과, 리뷰 수는 건대입구, 신촌, 안암, 샤로수길, 왕십리 순서였다. 건대 주변에 맛집이 많을 가능성이 있다. 그리고 샤로수길의 성장이 두드러졌다. 상권별 테마 비교하면, 왕십리 제외 모든 대학가에서 일중세계음식, 한식, 양식 순으로 식당이 많았다. 일중세계음식에는 일식, 중식, 그 외 세계음식이 모두 포함되어 있어 일중세계음식 식당의 수가 많게 측정되는 경향있었지만, 그럼에도 불구하고 한양대에서는 한식이 우세했다. 본 분석에는 '식신 사이트'에 대한 편향성과 일식, 중식, 세계음식을 하나의 카테고리로 통합하여 조사하여 보다 세부적인 테마별 분석이 이루어지지 못했다는 한계를 가지고 있다.

# %% [markdown]
# ## 1.실행환경
# - OS:
# - 파이썬 툴:
# - 데이터 수집 방법:
# - 필요 모듈:
#
# 예
# ```
# OS(윈도우, 리눅스, 맥 등)
# 파이썬 툴(colab, jupyter notebook, vs code 등)
# 데이터 출처 또는 수집방법(예, 인구데이터: 서울열린광장, 스타벅스 매장 데이터: 스타벅스 홈페이지에서 크롤링)
# 필요 모듈(bs4, selenium 등)
#
# ```

# %% [markdown]
# ## 2.사용된 데이터 출처

# %% [markdown]
# ## 3.전체코드

# %% [markdown]
# ## 4.부분코드 작성요령
#
# - 설명과 구현방법을 자세히 작성하세요. 부분코드는 기능별로 자유롭게 나누시면 됩니다.
# - 부분코드의 셀은 필요한만큼 추가하시면 됩니다.

# %% [markdown]
# ## 4-1. 부분코드1

# %% [markdown]
# ## 4-2. 부분코드2

# %% [markdown]
# ## 4-3. 부분코드3

# %% [markdown]
# ## 5.소감
# - 팀 프로젝트를 진행하면서 팀원 역할분담, 어려웠던 점, 느낀 점 등을 자유롭게 기술하시면 됩니다.
