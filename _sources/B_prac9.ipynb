# %% [markdown]
# # 실습 WEEK9: 웹크롤링

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 코딩수업(엘리스코딩)의 해당 주차 응시 기간을 확인해주세요.</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 주소 입력 받아 크롤링하기
# 😄 주소를 입력받아 해당 웹페이지를 크롤링해와서 변수 page에 저장하고 page를 HTML코드로 파싱하고 그 결과를 mysoup에 저장한 후 출력하시오.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample: 네이버 웹툰
# ```
# https://comic.naver.com/index
# ```
# Output Sample
# ```
# URL 입력:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>네이버 웹툰</title>
# <link href="https://ssl.pstatic.net/static/m/comic/im/favicon/1804/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
#
# 이하 생략
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample: 서울대학교 기초교육원
# ```
# https://liberaledu.snu.ac.kr/
# ```
# Output Sample
# ```
# URL 입력:
# <!DOCTYPE html>
#
# <html lang="ko">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <link href="https://liberaledu.snu.ac.kr/rss.xml" rel="alternate" title="기초교육원 RSS" type="application/rss+xml"/>
# ...
# <title>
# 	서울대학교
# 	 | 기초교육원</title>
#
# 이하 생략
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께) 네이버 금융데이터 추출하기

# %% [markdown]
# 😄 네이버 증권정보 사이트(https://finance.naver.com/marketindex/) 에서 환전 고시 환율, 국제 시장 환율, 유가.금시세 데이터를 아래와 같이 출력하시오.
#
# ```
# 미국 USD : 1,339.50
# 일본 JPY(100엔) : 999.51
# 유럽연합 EUR : 1,478.00
# 중국 CNY : 193.25
# 달러/일본 엔 : 134.1100
# 유로/달러 : 1.1011
# 영국 파운드/달러 : 1.2466
# 달러인덱스 : 101.2500
# WTI : 74.76
# 휘발유 : 1664.17
# 국제 금 : 1999.0
# 국내 금 : 85538.28
# ```

# %% [markdown]
# #### 1단계: urlopen()으로 웹페이지를 가져오기
# - 네이버 증권의 시장지표 사이트를 크롤링해보자.
# - 웹에서 추출하고자 데이터는 네이버 증권사이트에서 환전 고시 환율, 국제 시장 환율, 유가.금시세라고 가정해보자.
#
# - 먼저, 크롬 브라우저를 활용해 <font color="blue">네이버에 접속해서 증권 메뉴에서 시장지표를 클릭하여 해당사이트까지 이동</font>한다.
# - 브라우저의 주소 입력창에 나오는 링크를 복사한다.
# - 아래 코드의 urlopen()함수의 괄호안에 붙여넣는다.

# %%
from urllib.request import urlopen
page = urlopen('채워주세요')
#print(page)

# %% [markdown]
# #### 2단계: BeautifulSoup()으로 파싱하기
# - BeautifulSoup()을 활용해 HTML 파싱을 해서 soup객체로 만든다.

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup( '채워주세요' )
#print(soup) # 웹페이지 코드가 길어서 생략

# %% [markdown]
# #### 3단계: 개발자 도구 활용
# -  개발자 도구를 활용하여 추출하고자 하는 데이터가 어느 태그에 혹은 어떤 속성을 갖고 있는지 확인한다.
# - 이를 위해 개발자 도구 F12 또는 ... > 도구 더보기 > 개발자 도구를 클릭한다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/html5.png" style="width:600px;"></div>

# %% [markdown]
# - 요소(element) 선택 버튼을 클릭한다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/html6.png" style="width:600px;"></div>

# %% [markdown]
# - 추출하고자 하는 데이터는
#   - 환전 고시 환율, 국제 시장 환율, 유가.금시세 정보이다.
# - 추출하고자 하는 컨텐츠인 '미국USD'로 마우스를 가져가보자.
# - 마우스를 가져가면 도움말 기능으로 태그의 상세 정보인 h3.h_lst가 보인다.
# - 좀 더 자세히 확인해보기 위해 클릭한 후, 오른쪽의 소스보기 창의 음영처리 된 부분으로 가보자.
# - 미국USD라는 텍스트는 `<h3 class="h_lst">`에 들어있다.
# - 태그 옆에는 작은 삼각형이 보이는데, 이 삼각형을 클릭하여 소스보기를 접거나 펼칠 수 있다.
# - 삼각형을 눌러 펼쳐보면 `<span class="blind">미국 USD</span>`태그에 미국 USD 컨텐츠가 들어있다.
#
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/html7.png" style="width:600px;"></div>

# %% [markdown]
# - 추출하고자 하는 데이터를 몇 개 더 동일한 방법으로 확인해보자.
# - 일본JPY나 유로/달러 등의 컨텐츠도 동일한 태그인 것을 확인했다면 이제 그 태그를 이용하여 데이터를 추출할 수 있다.
# - 이때 태그를 잘 선택하는 것이 매우 중요하다. 우리는 두 가지의 옵션을 가지고 있다.
#   - 첫 번째 옵션은 ```<h3 class="h_lst">```로 태그가 h3이고 class가 h_lst인 컨텐츠를 찾는 것
#   - 두 번째 옵션은 ```<span class="blind">```로 태그가 span이고 class가 blind로 찾는 것
# - 어떤 태그로 찾는 것이 가장 최소한의 노력으로 헛일하지 않고 원하는 데이터를 추출할 수 있는지 생각해야 한다.
# - 어떤 태그를 활용해야 데이터를 잘 추출할 것인가는 여러 번의 연습과 시행착오를 거쳐서 감을 잡는 것이 필요하다.^^;;

# %% [markdown]
# #### 4단계: find_all()로 찾기
# - 두 가지 옵션 모두 테스트해보자. 먼저,` <h3 class="h_lst">`로 태그가 h3이고 class가 h_lst인 컨텐츠를 찾아보자.

# %%
soup.find_all('채워주세요.')

# %% [markdown]
# - 두 번째 방법은 `<span class="blind">`로 태그가 span이고 class가 blind로 찾아보자.
# - 두 번째 방법은 추출하려고 했던 데이터뿐만 아니라 원, 하락, 상승과 같은 필요하지 않은 데이터까지 포함되어 있다.

# %%
soup.find_all('채워주세요.')

# %% [markdown]
# - 그럼 find_all()로 찾은 요소들을 변수에 저장해보자.
# - find_all()의 결과는 'bs4.element.ResultSet'이다. 리스트는 아니지만 리스트처럼 보여지며, 리스트와 같이 접근이 가능하다. 즉, 인덱스를 활용한 접근과 반복문에 활용 할 수 있다는 것이다.

# %%
fList = soup.find_all('h3', class_="h_lst")
print(fList[0])
print(fList[0].string)

# %%
for each in fList:
  print(each.string)

# %% [markdown]
# 😄 환전 고시 환율, 국제 시장 환율, 유가.금시세의 가격을 추출하여 아래와 같이 출력해보자.
#
# ```
# 1,339.50
# 1,339.50
# 999.51
# 1,478.00
# 193.25
# 134.1100
# 1.1011
# 1.2466
# 101.2500
# 74.76
# 1664.17
# 1999.0
# 85538.28
# ```

# %% [markdown]
# 😄 환전 고시 환율, 국제 시장 환율, 유가.금시세 최종 데이터를 아래와 같이 출력해보자.
#
# ```
# 미국 USD : 1,339.50
# 일본 JPY(100엔) : 999.51
# 유럽연합 EUR : 1,478.00
# 중국 CNY : 193.25
# 달러/일본 엔 : 134.1100
# 유로/달러 : 1.1011
# 영국 파운드/달러 : 1.2466
# 달러인덱스 : 101.2500
# WTI : 74.76
# 휘발유 : 1664.17
# 국제 금 : 1999.0
# 국내 금 : 85538.28
# ```

# %% [markdown]
# ### Problem: (함께) 서울대학교 학부/학과 목록 추출하기
# 😄 서울대학교 대학웹페이지에서 학과/학부이름과 그 사이트 주소를 딕셔너리로 만드시오.
#
# 웹사이트 주소 : https://www.snu.ac.kr/academics/undergraduate/colleges
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# {'국어국문학과': ' https://korean.snu.ac.kr',
#  '중어중문학과': 'http://snucll.snu.ac.kr/',
#  '영어영문학과': 'https://english.snu.ac.kr/',
#  '불어불문학과': 'http://www.snufrance.com/home/main/index.asp',
#  '독어독문학과': 'http://german.snu.ac.kr/',
#  '노어노문학과': 'http://russian.snu.ac.kr/',
#  '서어서문학과': 'http://spanish.snu.ac.kr/html/main/index.html',
#  '아시아언어문명학부': 'http://asia.snu.ac.kr/',
#  '언어학과': 'http://linguist.snu.ac.kr/',
#  '국사학과': 'http://koreanhistory.snu.ac.kr/',
#  '동양사학과': 'http://asianhistory.snu.ac.kr/',
#  '서양사학과': 'http://whistory.snu.ac.kr/',
#  '철학과': 'http://philosophy.snu.ac.kr/board/html/main/index.php',
#  '종교학과': 'http://religion.snu.ac.kr/',
#  '미학과': 'http://meehak.snu.ac.kr/',
#  '고고미술사학과': 'http://www.archaeology-arthistory.or.kr/',
#  '정치외교학부(정치학전공)': 'http://polisci.snu.ac.kr/korean/',
#  '정치외교학부(외교학전공)': 'http://ir.snu.ac.kr/korean/',
#  '경제학부': 'http://econ.snu.ac.kr/',
#  '사회학과': 'http://sociology.snu.ac.kr/',
#  '인류학과': 'http://www.anthropology.or.kr/',
#  '심리학과': 'http://psych.snu.ac.kr/',
#  '지리학과': 'http://www.geog.snu.ac.kr/',
#  '사회복지학과': 'https://socialwelfare.snu.ac.kr/',
#  '언론정보학과': 'http://communication.snu.ac.kr/',
#  '수리과학부': 'http://www.math.snu.ac.kr/board/',
#  '통계학과': 'http://stat.snu.ac.kr/',
#  '물리천문학부(물리학전공)': 'https://physics.snu.ac.kr/',
#  '물리천문학부(천문학전공)': 'http://astro2.snu.ac.kr/',
#  '화학부': 'https://chem.snu.ac.kr/',
#  '생명과학부': 'http://biosci.snu.ac.kr/',
#  '지구환경과학부': ' https://sees.snu.ac.kr',
#  '간호학과': 'https://nursing.snu.ac.kr/',
#  '경영학과': 'http://cba.snu.ac.kr/',
#  '건설환경공학부': 'https://cee.snu.ac.kr/',
#  '기계공학부': 'http://me.snu.ac.kr/',
#  '항공우주공학과': 'http://aerospace.snu.ac.kr/',
#  '재료공학부': 'https://mse.snu.ac.kr/',
#  '전기·정보공학부': 'http://ee.snu.ac.kr/',
#  '컴퓨터공학부': 'https://cse.snu.ac.kr/',
#  '화학생물공학부': 'http://cbe.snu.ac.kr/',
#  '건축학과': 'http://architecture.snu.ac.kr/',
#  '산업공학과': 'http://ie.snu.ac.kr/',
#  '에너지자원공학과': 'http://ere.snu.ac.kr/',
#  '원자핵공학과': 'http://nucleng.snu.ac.kr/',
#  '조선해양공학과': 'http://ship.snu.ac.kr/',
#  '식물생산과학부': 'http://plantsci.snu.ac.kr/main.asp',
#  '산림과학부': 'http://forestry.snu.ac.kr/',
#  '응용생물화학부': 'http://abc.snu.ac.kr/',
#  '식품·동물생명공학부': 'http://fabio.snu.ac.kr/',
#  '바이오시스템·소재학부': 'http://bio4u.snu.ac.kr/',
#  '조경·지역시스템공학부': 'http://larse.snu.ac.kr/',
#  '농경제사회학부': 'http://aerd.snu.ac.kr/',
#  '디자인학부(공예)': 'http://art.snu.ac.kr/category/craft/',
#  '디자인학부(디자인)': 'http://art.snu.ac.kr/category/design/',
#  '교육학과': 'http://learning.snu.ac.kr/',
#  '소비자아동학부(소비자학전공)': 'http://consumer.snu.ac.kr/',
#  '소비자아동학부(아동가족학전공)': 'http://childfamily.snu.ac.kr/',
#  '식품영양학과': 'http://foodnutrition.snu.ac.kr/',
#  '의류학과': 'http://clothing.snu.ac.kr/',
#  '수의학과': 'http://vet.snu.ac.kr/',
#  '약학과': 'http://snupharm.snu.ac.kr/ko/node/251',
#  '제약학과': 'http://snupharm.snu.ac.kr/ko/node/252',
#  '의학과': 'http://medicine.snu.ac.kr/',
#  '자유전공학부': 'http://cls.snu.ac.kr/'}
#  ```

# %% [markdown]
# ### Problem: (스스로) 네이버의 뉴스 제목 가져오기
# 😄 네이버의 뉴스탭에서 뉴스 제목들만 추려서 출력하시오. 그 가운데 특정단어 예를 들어, '반려견', '부동산', 'AI', '대학생' 등의 단어가 들어가는 뉴스 제목을 리스트에 넣고 마지막에 출력하시오. 아래 Output Sample에서는 '반려견'이라는 단어가 들어있는 제목을 마지막에 출력하였다.
#
# <font color='blue'>`test case-1`</font>
# ---
#
# Output Sample
# ```
# 네이버 뉴스서 'URL·QR코드·언론사사이트' 이동 가능해진다
# 일본 언론 "내달 초 기시다 방한…한·일 정상회담 개최"
# “올 들어 코스피 상승률 2배 이상 오른 코스닥은 비정상”
# 尹대통령 "힘에 의한 현상변경 시도에 결연히 대응해야"
# “AI가 병원 돌진 명령" 환청 50대 공무원 승용차 대전 대학병원 돌진
# [현장에서]아직도 ‘4대강은 대운하가 아니다’라는 그들에게
# “보증금반환채권 매입, 피해자 먼저 고통에서 꺼내는 대책”
# 일본, 한국 '화이트리스트' 재지정 직후 기시다 방한 보도 잇따라
# “장비 알박기로 10억원씩 떼 가”···다단계 임금착취 판치는 하청의 현장
# 열차에 매달려 출근해 봤니? ‘인구 폭발’ 이 나라 [세계엔]
# "편한 복장에 배낭 메고"…尹 하버드 연설회장에 참석한 박영선
# 퍼스트리퍼블릭, 당국 개입설에 주가 70% 넘게 폭락…연준은 감독 실패 책임 인정
# [명품 컷] 시간마저 천천히 흐르는 힐링의 섬 청산도
# 박영선, 尹하버드대 연설에 백팩 메고 등장…그곳에 왜?
# 편한 복장에 배낭 메고…尹 하버드대 연설회장에 온 박영선
# “그밤의 진실 밝히면, 꿈에서라도 만나질까”
# [OK!제보] 동호회가 점령한 공공체육시설…술판까지 벌여 '눈살'
# 노래하며 즐거워하는 윤 대통령... 슬픕니다  [최현정의 웰컴 투 아메리카]
# 카드론 금리 내렸다는데…저신용자에겐 '남 일'
# 가족사진, 무료 촬영이라더니…‘인화’ 추가비용에 당했다 [다크패턴 맹추격③]
# [약손+] 아이들도 힘들다, '새 학기 증후군' ⑧언어발달장애
# 檢 '돈봉투 의혹' 중심 정조준…송영길 주거지 등 압수수색
# [尹국빈방미]尹, 韓美동맹 미래는 '과학기술 협력'
# BMW iX5 하이드로젠, 전기차 충전 고통 끝내나 [CAR톡]
# 오늘도 달린다 '황금마차'...MZ 장병 최고 인기 품목은?
# "이런 건 처음 봐…방명록에 '대한민국 대통령 배우자 김건희'라고 적더라"
# 제품명도 ‘한글’…“日라면회사, 불닭볶음면 모방으로 한국에 복수”
# '아메리칸 파이' 뒷이야기…바이든 즉석 요청, 윤 대통령 '깜짝' 열창
# 디지털 안전자산? 은행 위기 때마다 반등하는 비트코인
# 검찰, '전대 돈봉투 의혹' 송영길 전 대표 압수수색
# 한국 1인당 GDP, 18년만에 이 나라한테 추월당했다
# 러軍 기습공격, 대공세 신호탄? “대학생 표적 징병” 2차 동원 공포 [월드뷰]
# 한은 “스마트폰만 있으면 입출금 가능하게 할 것”…‘2022년 지급결제보고서’ 내용은
# 아이 버리고 부끄러움도 버린 한국
# 100억 전세, 월세는 4000만원…장동건·고소영의 그사세 아파트[부동산360]
# "한국도 베꼈잖아, 복수"…불닭볶음면 표절 논란 분석한 日매체
# 日 언론 "북한, 러시아 용병 바그너그룹에 포탄 1만발 제공" 보도
# 넷플릭스, 25억 달러 투자 평가절하한 정청래에 반박
# 구글, 애플… '쥐꼬리 이익률' 속 탐욕과 농락 [視리즈]
# "형도 친부도 계모도 살해하고".. 자신도 극단 선택
# Yoon Suk Yeol becomes first Korean president to give address at Harvard
# 성매매 2400회 강요·4세 학대살해 방조 혐의 동거녀, 재판서 혐의 부인
# "에어백 터졌는데도"...월세 밀려 쫓겨나자 집주인 향해 '부웅'
# "출생신고한 비혼부들의 '고맙다'는 말에 보람"… 포기 모르는 '사랑이 아빠'
# '존귀하신 자제분'에서 '사랑하는 자제분'으로 톤다운 된 김정은 딸
# 김건희 여사, 보스턴미술관 방문…"한국 문화소개하는 특별전이 개최되도록 관심 가져달라"
# Viral respiratory infections surge after lifting of mask mandate
# 北 김여정 "바이든, 정권종말 발언은 늙은이 망언"
# “총선 지면 尹 레임덕? 당장 올해 여름이 위기” [+영상]
# 살 빠지는 탄수화물도? 무조건 경계는 역효과
# "임창정, 부인 서하얀과 주가조작 일당 '1조원 돌파 파티' 참석"
# 애플워치, 아이패드·맥과도 연동될까
# "아파트·재산 다줬는데 양육비도?"… 재혼 앞둔 男, 전처 요구에 고민
# 제주 무인도에 잠입한 30대 커플..'불법 캠핑'하다 불냈다
# 검찰, '돈봉투 의혹' 송영길 전 민주당 대표 압수수색
# '음료에서 이상한 맛이...' 공무직 마시던 음료서 제초제 성분 발견
# 1억 5천짜리 바나나 또 먹혔다, 이번엔 서울대생…"배고팠다"
# 김여정 “바이든, 늙은이의 망언”“윤석열은 못난 인간”
# [반려견 산행] '펫티켓'…반려견 산행 위한 첫걸음
# K-콘텐츠 점령한 ‘센 언니’들…유리 천장 뚫는 여성 서사의 진화[K-콘텐츠 뒤흔드는 걸크러쉬]
# `주가 조작` 투기세력이 노린 8개 종목… 범행 `먹잇감`된 결정적 이유
# 윤 대통령 ‘아메리칸 파이’···백악관의 ‘치밀한 빌드업’ 있었다
# 尹, 하버드대 연설 "'허위 선동·가짜 뉴스'가 민주주의 흔들고 자유 위협"
# 원빈 이나영 청담동 145억 빌딩...5년 만에 150억 대박?
# 검찰, ‘전대 돈봉투’ 송영길 전 민주당 대표 압수수색
# 티빙 "가정의 달 함께 즐겨요" 연휴 추천 라인업 공개 [위클리콘]
# 유동규, 이재명에 “형님 정신병원 집어넣게 시켰잖아요!”…법정서 충돌
# ‘학폭 폭로’ 표예림 찾아온 高교장…“정말 미안하다”
# "민간 방송 공정성을 누가 심판할 수 있나"
# 하버드 출신 26세 시장 당선 화제…외신들도 깜짝[일본人사이드]
# 우리 아이 눈, 나이에 맞게 자라는 지 확인하는 법
# 성별에 대해 우리가 갖는 ‘두려움’
# 마을 돌고 도장 '꾹'…"그럼 선물이 쏟아집니다"
# "바글바글했었는데"…'휴대폰 성지' 테크노마트의 몰락 [현장+]
# 안성기 “이 시련도 배우에겐 금은보화… 내년 봄엔 촬영장에 있을 것”
# 승용차로 대학병원 돌진한 공무원…"AI 지시받았다" 횡설수설
# 오픈넷 前 이사장, '횡령·배임 의혹' 이사 형사 고발
# 국내 연구진, 세계 최고 수준 차세대 유전자가위 설계기술 개발
# [법잇수다] 동료 커피에 락스.. 직장 따돌림이 빚은  비극
# 배달의 민족은 온몸이 아프다 [밥 먹다가 울컥]
#
# ["[반려견 산행] '펫티켓'…반려견 산행 위한 첫걸음"]
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 날씨정보 크롤링하기
# 😄 기상청 홈페이지의 날씨 > 예보 > 단기예보 페이지에서 아래와 같이 날씨 정보를 추출하시오.
#
# https://www.weather.go.kr/w/weather/forecast/short-term.do 에서
# <font color='blue'>`test case-1`</font>
# ---
# Output Sample
# ```
# 예보요소 	평년(오늘) 	어제(28일) 	오늘(29일) 	내일(30일) 	모레(01일)
# 최저기온 (℃) 	6.7 ~ 12.3 	2.2 ~ 15.2 	11.9 ~ 17.9 	6 ~ 13 	5 ~ 13
# 최고기온 (℃) 	19.2 ~ 23.3 	19.3 ~ 26.8 	15 ~ 25 	16 ~ 24 	18 ~ 24
# ```
